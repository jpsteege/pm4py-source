# %%
import os
storagePath = '/Users/jpsteege/Documents/PM4Py/pm4py-source/'

# %%
from pm4py.objects.log.importer.xes import factory as xes_importer
from pm4py.algo.discovery.alpha import factory as alpha_miner

# %%
log = xes_importer.import_log(os.path.join(storagePath+'tests',"input_data","running-example.xes"))

# %%
net, initial_marking, final_marking = alpha_miner.apply(log)

# %%
print(net)
# Out:
# <pm4py.objects.petri.petrinet.PetriNet object at 0x10d385f60>

# %%
from pm4py.visualization.petrinet import factory as pn_vis_factory

gviz = pn_vis_factory.apply(net, initial_marking, final_marking)
pn_vis_factory.view(gviz)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2600b5703b25> in <module>()
# ----> 1 print(log)
#
# NameError: name 'log' is not defined
